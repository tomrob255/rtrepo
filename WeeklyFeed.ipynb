# %%
#WeeklyFeed allows to monitor food elements supply for a week.

# %%
# 1. Foods definition
# Object 1: dictionary. Key: food Value Proteins g /100g
# Object 2: dictionary. Key: food Value Energy kcal /100g

foods_p = {
    'pollo': 10,
    'pasta': 3}

foods_e = {
    'pollo': 4,
    'pasta': 14
}

print(foods_p)
print(foods_e)
# Out:
# {'pollo': 10, 'pasta': 3}
# {'pollo': 4, 'pasta': 14}

# %%
# 2. Meal definition

meal = [
    ['pasta', 80],
    ['pollo', 150]
]

#Example:
for food in meal:
    print(food[0]+'\t'+str(food[1]))
print('Meal completed')
# Out:
# pasta	80
# pollo	150
# Meal completed

# %%
#Food class definition
class Food:
    counter = 0
    
    def __init__(self, name, energy = 0, proteins = 0):
        self.counter += 1
        Food.counter += 1
        self.name = name
        self.energy = energy
        self.proteins = proteins
    
    def getName(self):
        return self.name
    
    def getProteins(self):
        return self.proteins
    
    def getEnergy(self):
        return self.energy

    @classmethod
    def getFoodsCounter(cls):
        return cls.counter
    
#FoodList
class FoodList():
    
    FoodListCounter = 0
    
    def __init__(self):
        self.FoodList = list()
        self.FoodListCounter = 0
    
    def addFood(self, name, proteins, energy):
        self.FoodList.append(Food(name, proteins, energy))
    
    def showFoods(self):
        print("\tFood List:\n")
        print("Name \t Proteins \t Energy")
        for elementIndex in range(self.FoodList().getFoodsCounter()):
            food = self.FoodList(elementIndex)
            print(food.getName + "\t" + str(food.getProteins()) + "\t" + str(food.getEnergy()))
        
        print("No. of elements: " + str(slef.FoodList[0].getFoodsCounter()))
        print("\n \t List completed")

# %%
# Foods population

myFoodList = FoodList()
myFoodList.addFood("pasta", 5, 150)
myFoodList.addFood("pollo", 20, 10)
myFoodList.addFood("albume", 50, 10)

#myFoodList.showFoods()
print("ciao")
print(str(myFoodList.FoodListCounter))
# Out:
# ciao
# 0

# %%
f1 = Food("pasta", 5, 150)
f2 = Food("pollo",20, 1)

f2.getName()
Food.counter
# Out:
# 2
