# %%
#WeeklyFeed allows to monitor food elements supply for a week.

# %%
# 1. Meal class definition
class Food:
    def __init__(cls):
        # inizializzare i dati relativi ai singoli cibi: name, prot, eng
        cls.type =
